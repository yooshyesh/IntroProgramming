# %% [markdown]
# Prüfungsstoff
# >Mentifragen
# >Codealternativen
# >Leerer Code
#
# Übungen aus den Lektionen
#
# Themen zum repetieren
# for i, j in range:-Aufgabe
# Zusammenfassung:
# random-Bibliothek
# __init__
# UML-Regeln
# len, append etc.

# %% [markdown]
# # OOP3: Objekte im All
#
# Dieses Notebook führt die vorherigen Übungen (Fahrzeuge & Zoo) weiter.
# Hier erkunden wir OOP-Konzepte im **Weltraum-Kontext**.
# Ziel: Erkennen, wann Klassen, Vererbung und Polymorphie sinnvoll sind sowie fehlerhafte Umsetzungen identifizieren.

# %% [markdown]
# ## Aufgabe 1 – Wähle den richtigen Code für die Raumstation
# Finde die richtigen Methoden aus dem Kommentar und füge sie ein, so soll sich ein funktionierender und logischer Code ergeben.

# %%
class Raumstation:
    def __init__(self, name, energie=100.0):
        self.name = name
        self.crew = []
        self.energie = energie

    def add_astronaut(self, astronaut):
        self.crew.append(astronaut)

    def verbrauch_energie(self, menge):
        if menge > self.energie:
            print(f"{self.name}: Nicht genug Energie!")
            self.energie = 0
        else:
            self.energie -= menge
    
    def status(self):
        return f"{self.name}: Crew={len(self.crew)}, Energie={self.energie:.1f}%"

'''
# Variante A X self.crew wird überschrieben
def add_astronaut(self, astronaut):
    self.crew = astronaut 

# Variante B
def berechne_orbit(self, radius): X wird unten nicht aufgerufen
    print("Berechne Umlaufbahn... (aber eigentlich mache ich nichts)")

# Variante C

# Variante D
def teleportiere(self, ziel): X wird unten nicht aufgerufen
    print(f"Teleportiere Crew nach {ziel}... oh, warte, geht ja gar nicht!")

# Variante E
def add_astronaut(self, name): X So wird es nicht zur Liste hinzugefügt
    self.crew += name

# Variante F
def verbrauch_energie(self, menge): X Menge wird hinzugerechnet anstatt abgezogen
    self.energie += menge

# Variante G

# Variante H X self.power wird überschrieben, wird unten nicht aufgerufen
def set_energie(self, wert):
    self.power = wert
        
# Variante J X auf 2 Stellen gerundet anstatt 1
def status(self):
    return f"Energielevel: {self.power:.2f}"
'''


# Testausgabe
s = Raumstation("ISS")
s.add_astronaut("Alex")
s.add_astronaut("Sam")
s.verbrauch_energie(30)
print(s.status())

# Erwartete Ausgabe:
# ISS: Crew=2, Energie=70.0%
# Out:
# ISS: Crew=2, Energie=70.0%

# %% [markdown]
# ## Aufgabe 2 – Wähle den richtigen Code zum Sensor
#
# Der Sensor misst Temperaturdaten auf einem Planeten.
# Wähle die passenden Methoden aus dem Kommentar.

# %%
class Sensor:
    def __init__(self, ort):
        self.ort = ort
        self.wert = 0.0

    def status(self):
        return f"{self.ort}: {self.wert:.2f}°C"
    
    def messen(self, temperatur):
        self.wert = temperatur
        print(f"Messung in {self.ort}: {self.wert}°C")

'''
# Variante A
    

# Variante B X Wert: kommt nicht im Output vor
    def status(self):
        return f"Wert={self.value}"

# Variante C X Messung: kommt nicht im Output vor, Ort fehlt
    def messen(temperatur): 
        print(f"Messung: {temperatur}°C")

# Variante D X return 42
    def messen(self, temperatur):
        self.wert = temperatur
        return 42

# Variante E X Neue Temperatur kommt nicht im Output vor
    def messen(self, temperatur):
        self.wert += temperatur
        print(f"Neue Temperatur: {self.wert}")

# Variante F 


# Variante G X Ort geändert kommt nicht im Output vor
    def messen(self, ort):
        self.ort = ort
        print(f"Ort geändert auf {self.ort}")

# Variante H X Auf ganze Zahl gerundet
    def status(self):
        return f"{self.ort}: Temperatur={round(self.wert)} Grad"
'''

# Testcode
s = Sensor("Labor")
s.messen(22.8)
print(s.status())

# Erwartete Ausgabe:
# Messung in Labor: 22.8°C
# Labor: 22.80°C
# Out:
# Messung in Labor: 22.8°C
# Labor: 22.80°C

# %% [markdown]
# ## Aufgabe 3 – Wähle den richtigen Code für die Energiezelle
# Die Energiezelle soll Energie speichern und abgeben können.
# Wähle die passenden Methoden.

# %%
# Variante B X wird nicht aufgerufen
#    def aufladen(self):
#        print("Energie wird geladen...")
        
        
class Energiezelle:
    def __init__(self, kapazitaet=100):
        self.kapazitaet = kapazitaet
        self.energie = kapazitaet

    def entladen(self, menge):
        if menge > self.energie:
            print("Nicht genug Energie!")
            self.energie = 0
        else:
            self.energie -= menge

    def status(self):
        return f"Energie: {self.energie}/{self.kapazitaet}"


'''
# Variante A


# Variante C
    def entladen(self, menge):
        self.kapazitaet -= menge

# Variante D


# Variante E
    def entladen(self, menge):
        self.energie += menge

# Variante F X kein /
    def status(self):
        return f"Energie: {self.kapazitaet}"

# Variante G 
    def entladen(self, menge):
        self.energie = 0

# Variante H X kein f string
    def status(self):
        return ["Energie:", self.energie, "/", self.kapazitaet]

# Variante I # kein Output ohne print/return
    def entladen(self, menge):
        rest = self.energie - menge
        if rest < 0:
            self.energie = menge  # falsch herum
        else:
            self.energie = rest
'''

z = Energiezelle(50)
z.entladen(20)
print(z.status())
z.entladen(40)
print(z.status())

# Erwartete Ausgabe:
# Energie: 30/50
# Nicht genug Energie!
# Energie: 0/50
# Out:
# Energie: 30/50
# Nicht genug Energie!
# Energie: 0/50

# %% [markdown]
# ## Aufgabe 4 – Klassen implementieren
# Erstelle die Klassen `Planet`, `Raumschiff` und `Astronaut`.
# Achte auf sinnvolle Attribute und Methoden.
# Implementiere die TODOs und begründe kurz im Kommentar, warum du diese Struktur gewählt hast.

# %%
class Planet:
    def __init__(self, name, atmosphaere, bewohner=0):
        self.name = name
        self.atmosphaere = atmosphaere
        self.bewohner = bewohner

    def landen(self):
        print(f"Ein Raumschiff landet auf {self.name}.")

    def info(self):
        print({self.name}, {self.atmosphaere}, {self.bewohner})


class Raumschiff:
    def __init__(self, name, treibstoff=100):
        self.name = name
        self.treibstoff = treibstoff

    def fliegen(self, entfernung):
        self.entfernung = entfernung
        return entfernung * 0.5
        # TODO: prüfen, ob genug Treibstoff vorhanden ist
        # TODO: Meldung ausgeben und Treibstoff anpassen
        pass

    def status(self):
        # TODO: Status zurückgeben mit aktuellem Treibstoffstand
        pass


class Astronaut:
    def __init__(self, name, erfahrung=0):
        # TODO: Attribute speichern
        pass

    def mission(self):
        # TODO: Erfahrung um 1 erhöhen und eine Meldung ausgeben
        pass

## TEST
erde = Planet("Erde", "Sauerstoff", 8_000_000_000)
apollo = Raumschiff("Apollo")
anna = Astronaut("Anna")

erde.landen()
apollo.fliegen(50)
anna.mission()
print(erde.info(), apollo.status())

# %% [markdown]
# ## Aufgabe 5 – Vererbung & Polymorphie
#
# Implementiere eine Klassenhierarchie:
# - Himmelskoerper (Basisklasse)
# - Planet und Stern (Unterklassen)
#
# Jede Klasse soll eine Methode beschreibung() besitzen, die unterschiedlich funktioniert.

# %%
# TODO: Erstelle eine Basisklasse Himmelskoerper
# - Attribute: name, masse
# - Methode: beschreibung()

# TODO: Erstelle eine Unterklasse Planet
# - Zusätzliche Attribute: bewohner
# - Überschreibe beschreibung()

# TODO: Erstelle eine Unterklasse Stern
# - Zusätzliche Attribute: temperatur
# - Überschreibe beschreibung()

## Test
objekte = [
    Planet("Mars", 6.39e23, 0),
    Stern("Sonne", 1.99e30, 5500),
    Himmelskoerper("Asteroid B-612", 1.2e15)
]

for o in objekte:
    print(o.beschreibung())

# Erwartete Ausgabe:
# Mars ist ein Planet mit 0 Bewohnern.
# Sonne ist ein Stern mit 5500°C Oberflächentemperatur.
# Asteroid B-612 ist ein allgemeiner Himmelskörper.

# %% [markdown]
# ## Aufgabe 6 – Startercode ergänzen
#
# Fülle die TODOs im Code aus, damit das Programm funktioniert.

# %%
class Rakete:
    def __init__(self, name, stufe=1):
        self.name = name
        self.stufe = stufe
        self.status = "bereit"

    # TODO: Methode starten() implementieren
    # TODO: Methode landen() implementieren
    # TODO: Methode info() implementieren

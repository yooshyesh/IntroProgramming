# %% [markdown]
# Prüfungsinhalte
# Mentifragen
# Codealternativen
# Leerer Code
# Übungen aus den Lektionen

# %%
for i in range(3):
    for j in range(2):
        if i == j:
            continue
        print(i, j)
# Out:
# 0 1
# 1 0
# 2 0
# 2 1

# %% [markdown]
# Methoden werden beide automatisch aufgerufen, wenn Instanz aufgerufen wird.
# __init__ > Konstruktor
# self
# __str__ >
# Repräsentiert string-Variante des Klassenobjektes
# Wird durch print oder return ausgegeben

# %% [markdown]
# super().__init__(x)
# Setz alle Instanzattribute der Vererberklasse an die erbende Klasse

# %%
class Motorrad(Fahrzeug):
    reifen = 3.2482
    def __init__(self, marke, hubraum):
        super().__init__(marke)
        # self.marke = marke setzt Vererbung ausser Kraft
        self.hubraum = hubraum
        self.marke = marke # Instanzvariable

    def massreifi(self):
        Motorrad.reifen * 3

Moto = Motorrad()
print(Moto.massreifi())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 12
#       9     def massreifi(self):
#      10         Motorrad.reifen * 3
# ---> 12 Moto = Motorrad()
#      13 print(Moto.massreifi())
#
# TypeError: Motorrad.__init__() missing 2 required positional arguments: 'marke' and 'hubraum'

# %%
def process(nums):
    for n in nums:
        if n < 0:
            continue
        print(n)

parameter = [-1, 0, 1] # softcoded
process(parameter)
# Out:
# 0
# 1

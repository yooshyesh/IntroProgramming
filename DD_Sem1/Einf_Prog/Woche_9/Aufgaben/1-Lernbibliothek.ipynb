# %% [markdown]
# # Lernbibliothek
# In diesem Kapitel begleiten wir eine Lernsession von Studierenden und verwenden dabei diverse Bibliotheken.

# %%
import datetime
import math
import random

# %% [markdown]
# ## Fragenkatalog
# Um deine Python-Kenntnisse zu verbessern, hast du eine Sammlung von Karteikarten erstellt.
#
# Das Programm soll...
# - ...alle Karten in zufälliger Reihenfolge abfragen.
# - ...die Antwort nach Drücken von Enter anzeigen.
# - ...nachdem alle Karten abgefragt wurden eine Erfolgsmeldung ausgeben.

# %%
# Liste von Karteikarten
karteikarten = [
    {"frage": "Was ist eine Liste in Python?", "antwort": "Eine geordnete, veränderbare Sammlung von Elementen."},
    {"frage": "Wie erstellt man ein Dictionary?", "antwort": "Mit geschweiften Klammern: z.B. {'key': 'value'}"},
    {"frage": "Was macht die 'len()'-Funktion?", "antwort": "Gibt die Anzahl der Elemente eines Objekts zurück."},
    {"frage": "Wie kommentiert man eine Zeile in Python?", "antwort": "Mit einem '#' am Anfang der Zeile."},
    {"frage": "Was ist eine Funktion?", "antwort": "Ein Block von Code, der eine Aufgabe erfüllt und wiederverwendbar ist."}
]

# TODO: Karten mischen
for entry in karteikarten:
    return random.choice()

print("Python Karteikarten – starte das Quiz!\n")

# TODO: Abfrage-Schleife implementieren
for # ...
    input(f"Frage: {karte['frage']}\nDrücke Enter, um die Antwort zu sehen...")
    # TODO: Antwort anzeigen
    
    input("Drücke Enter für die nächste Karte...\n")

print("Alle Karten abgefragt – gut gemacht!")

# %% [markdown]
# ### Bonus
# Nun wird noch eine zufällige Auswahl an Karten festgelegt damit nicht der ganze Katalog abgefragt wird.

# %%
# nach karteikarten = [ ... ]
# TODO: restliches Programm ergänzen
anzahl_karten = random.randint(3, len(karteikarten))
auswahl_karten = random.sample(karteikarten, k=anzahl_karten)

# vor zufälliger Reihenfolge

# %% [markdown]
# ## Zeitplan
# Erstelle ein Programm, das für mehrere Lerneinheiten einen Zeitplan berechnet.
#
# Das Programm soll:
#
# 1. Nach der Anzahl der Lerneinheiten fragen.
# 2. Für jede Einheit einen Namen erfassen (`input(f"Name für Einheit {i}: "`)).
# 3. Start- und Endzeiten jeder Einheit berechnen und ausgeben. Verwende feste Zeiten (z.B. 45 Minuten Lernen, 15 Minuten Pause).
#
# **Hinweis:** Verwende `datetime.timedelta` und `datetime.datetime.now()`.
#
# **Beispiel:**
#
#     Wie viele Lerneinheiten willst du heute machen? 3
#     Name für Einheit 1: Einheit 1
#     Name für Einheit 2: Einheit 2
#     Name für Einheit 3: Einheit 3
#
#     Dein Lern-Zeitplan für heute:
#     Start: 21:44
#
#     Einheit 1: Einheit 1
#        Lernen von 21:44 bis 22:29
#        Pause von 22:29 bis 22:44
#
#     Einheit 2: Einheit 2
#        Lernen von 22:44 bis 23:29
#        Pause von 23:29 bis 23:44
#
#     Einheit 3: Einheit 3
#        Lernen von 23:44 bis 00:29

# %%
# Schritt 1: Anzahl der Einheiten abfragen
anzahl = int(input("Wie viele Lerneinheiten willst du heute machen? "))

# Schritt 2: Namen der Einheiten sammeln
einheiten = []
# TODO: Namen der Einheiten erfassen

# Schritt 3: Parameter festlegen
start = datetime.datetime.now()
lern_dauer = datetime.timedelta(minutes=45)   # feste Lernzeit: 45 Minuten
pause_dauer = datetime.timedelta(minutes=15) # feste Pausenzeit: 15 Minuten

# TODO: 
aktueller_start = 0 # Todo


# Schritt 4: Zeitplan berechnen & ausgeben
print("\nDein Lern-Zeitplan für heute:")

# Mit strftime() kann ein datetime-Objekt als formatierter Text ausgegeben werden.
# '%H:%M' steht für Stunden und Minuten im 24-Stunden-Format (z.B. 14:30).
print(f"Start: {start.strftime('%H:%M')}\n")

# enumerate() liefert Tupel aus Index und Wert
# Aus ["Mathe", "Informatik"] wird (1, "Mathe"), (2, "Informatik")
# Das ist praktisch, wenn man den Index und den Namen des Elements gleichzeitig braucht.
# Der Index wird in i und das Element wird in name gespeichert.
for i, name in enumerate(einheiten, start=1):
    lern_ende = aktueller_start + lern_dauer
    print(f"Einheit {i}: {name}")
    print(f"   Lernen von {aktueller_start.strftime('%H:%M')} bis {lern_ende.strftime('%H:%M')}")

    if i < anzahl:  # Pause nur einfügen, wenn nicht die letzte Einheit
        # TODO: pause_ende definieren
        print(f"   Pause von {lern_ende.strftime('%H:%M')} bis {pause_ende.strftime('%H:%M')}\n")
        # TODO: aktueller_start neu definieren
    else:
        print("\nAlle Einheiten abgeschlossen.")

# %% [markdown]
# ## Pizzabestellung
# Um sich zu stärken wird Pizza bestellt. Da Mathe mega cool ist, möchten die Studierenden genau wissen wie gross die Fläche ihrer Pizza ist.
# Die Studierenden wollen berechnen, wie gross die Fläche ihrer Pizza ist.
#
# Schreibe ein Programm, das:
# 1. die Anzahl der Pizzen abfragt
# 2. für jede Pizza den Radius einliest
# 3. für jede Pizza die Fläche und den Umfang berechnet und ausgibt
#
# Tipp: Verwende `math.pi`, `**` für Potenzen (z.B. für $r^2$) und formatiere das Ergebnis auf zwei Dezimalstellen (`variable.2f`).
#
# - Umfang: $U=2πr$
# - Fläche: $A=πr^2$

# %%
anzahl = int(input("Wie viele Pizzen sollen berechnet werden? "))

# TODO: Schleife über alle Pizzen
for...:
    # TODO: Radius abfragen pro Pizza, Eingabe in int konvertieren, da wir nur mit Zahlen rechnen können

    # TODO: flaeche und umfang berechnen

    print(f"Pizza {i}:")
    print(f"   Fläche: {flaeche:.2f} cm²")
    # TODO: Umfang (Rand) ausgeben

# %% [markdown]
# # Schachbrett-Validierung
#
# In diesem Kapitel verwenden wir ein Dictionary, um ein Schachbrett darzustellen.
#
# image::imgs/chessboard.jpg[400,400]

# %%
# Dieses Dictionary repräsentiert die aktuelle Stellung auf einem Schachbrett.
# Der Schlüssel ist die Position auf dem Brett (z. B. '1h'), bestehend aus Zeile (1–8) und Spalte (a–h).
# Der Wert ist die Spielfigur auf diesem Feld, bestehend aus:
# - einem Buchstaben für die Farbe: 'w' = weiss (white), 'b' = schwarz (black)
# - und dem Namen der Figur: 'pawn' (Bauer), 'knight' (Springer), 'bishop' (Läufer), 'rook' (Turm), 'queen' (Dame), 'king' (König)
# Beispiel: '1h': 'bking': Auf Feld 1h steht der schwarze König.
# Felder, die im Dictionary nicht vorkommen, sind leer.
position = {'1h': 'bking', '6c': 'wqueen', '2g': 'bbishop', '5h': 'bqueen', '3e': 'wking'}

# %% [markdown]
# Schreibe eine Funktion mit dem Namen ```isValidChessBoard()```, die ein Dictionary als Argument erhält und True oder False zurückgibt. Wenn die Position auf dem Schachbrett gültig ist, wird `True` zurückgegeben, andernfalls `False`.
#
# Bedingungen für ein gültiges Schachbrett:
# 1. Genau ein weisser König und ein schwarzer König.
# 2. Jede Farbe höchstens 16 Figuren.
# 3.	Jeder Spieler darf höchstens 8 Bauern (pawns) haben.
# 4.	Alle Figuren müssen auf einem gültigen Feld von '1a' bis '8h' stehen.
#
# Ein Feld wie '9z' ist ungültig.
# 5.	Die Namen der Figuren müssen mit 'w' (weiss) oder 'b' (schwarz) beginnen, gefolgt von:
#    - 'pawn', 'knight', 'bishop', 'rook', 'queen' oder 'king'.
#
# # Ziel der Funktion
#
# Die Funktion ```isValidChessBoard()``` soll überprüfen, ob das Dictionary alle Anforderungen erfüllt. Sie soll Fehler erkennen, die z. B. durch Programmierfehler bei der Darstellung des Schachbretts entstanden sind.

# %%
def isValidChessBoard(board: dict[str, str]) -> bool:
    # Set mit allen gültigen Positionen erstellen ("a1", "a2", "a3",...)

    valid_positions = set()
    # Todo...

    valid_pieces = {'pawn', 'knight', 'bishop', 'rook', 'queen', 'king'}

    piece_counts = {
        'w': {'total': 0, 'pawn': 0, 'king': 0},
        'b': {'total': 0, 'pawn': 0, 'king': 0}
    }

    for position, piece in board.items():
        # Prüfe, ob das Feld gültig ist

        # Prüfe, ob der Name der Figur gültig ist

        color = piece[0]
        name = piece[1:]

        # Zähle die Figuren

    # Regeln prüfen
    for color in 'wb':
        if (piece_counts[color]['total'] > 16 or
            piece_counts[color]['pawn'] > 8 or
            piece_counts[color]['king'] != 1):
            return False

    return True

# Test mit dem Beispiel-Board
test_board = {'1h': 'bking', '6c': 'wqueen', '2g': 'bbishop', '5h': 'bqueen', '3e': 'wking'}
isValidChessBoard(test_board)

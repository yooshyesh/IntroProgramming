# %% [markdown]
# # Aufgabe
#
# ## Wichtig
# Vergiss bei deinen Projekten nicht die Bibliotheken und schreibe die nötigen ```import```-Statements wenn es sinnvoll ist.
#
# ## Aufgabe 1: Daten aus einer Datei laden
# Schreibe eine Python-Funktion, welche die JSON-Datei ```usability_data.json``` einliest und als Liste von Dictionaries speichert. Verwende bei deiner Lösung die ```json```-Bibliothek.

# %%
# Import ...

def load_usability_data(filepath):
    # Dein Code...
    return data

load_usability_data("usability_data.json")
# Ausgabe: [{'success': True, 'duration': 30, 'backtracks': 1}, ...]

# %% [markdown]
# ## Aufgabe 2: Analyse
# Schreibe eine Python-Funktion, welche die eingelesenen Daten entgegennimmt und die nachfolgenden Auswertungen zurückgibt. Du kannst dabei auf deinen Code aus der vergangenen Woche zurückgreifen.
#
# Teilaufgaben:
# - Wie viele Personen haben die Aufgabe erfolgreich abgeschlossen?
# - Wie hoch war die durchschnittliche Bearbeitungsdauer?
# - Erstelle eine Liste von Personen, die mehr als 2 Mal zurückgesprungen sind und dennoch erfolgreich waren.

# %%
def analyze_data(data):
    # Dein Code...
    return success_count, avg_duration, filtered_users

# Ausgabe: (3, 57, [])

# %% [markdown]
# ## Aufgabe 3: Ergebnisse speichern
# Schreibe die Ergebnisse der Auswertungen aus Aufgabe 2 in eine neue Textdatei (z.B. ```evaluation.txt```).
#
# Verwende ein leserliches Format wie:
#
# ```
# Erfolgreiche Nutzer:innen: 3
# Durchschnittliche Dauer: 57 Sekunden
# Nutzer:innen mit >2 Backtracks und Erfolg:
# - Dauer: 60, Backtracks: 3
# ```

# %%
def write_evaluation_to_file(filepath, success_count, avg_duration, filtered_users):
    # Dein Code...

# %% [markdown]
# ## Aufgabe 4: CSV-Verarbeitung
#
# Du erhältst die Daten zusätzlich auch als CSV-Datei (```usability_data.csv```) mit den Spalten: ```user_id```, ```success```, ```duration```, ```backtracks```. Schreibe eine Funktion, die die Datei einliest und in die bestehende Analyse integriert.

# %%
def load_csv_data(filepath):
    # Dein Code...
    return data

load_csv_data("usability_data.csv")
# Ausgabe: [{'success': True, 'duration': 30, 'backtracks': 1}, ...]

# %% [markdown]
# ## Aufgabe 5 (Bonus): Benutzer mit besonders schlechtem Ergebnis markieren
# Füge eine zusätzliche Analyse ein, bei der User mit einer Dauer > 80 Sekunden und mehr als 3 Backtracks als struggling markiert werden.
#
# Diese User werden in einer separaten Datei ```struggling_users.json``` gespeichert.

# %%
def save_struggling_users(data, filepath):
    # Dein Code...

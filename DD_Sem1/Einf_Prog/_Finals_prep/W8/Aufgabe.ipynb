# %% [markdown]
# # Aufgabe
#
# ## Auswertung eines Usability-Tests
#
# Du arbeitest in einem UX-Team und hast einen Usability-Test durchgeführt. Die Testpersonen sollten eine Aufgabe in deiner App lösen, z. B. ein Formular ausfüllen oder ein Produkt in einem Shop finden. Für jede Sitzung wurde festgehalten:
# - Ob die Aufgabe erfolgreich gelöst wurde (```success = True``` oder ```False```)
# - Wie lange sie mit der Aufgabe beschäftigt waren (```duration```in Sekunden)
# - Wie oft sie bei der Lösung den Back-Button des Browsers verwendet haben (```backtracks```)
#
# Die Daten liegen als eine Liste von Dictionaries vor. Jedes Dictionary repräsentiert den Datensatz einer Sitzung.

# %%
test_data = [
    {"success": True,  "duration": 30, "backtracks": 1},
    {"success": False, "duration": 75, "backtracks": 4},
    {"success": True,  "duration": 30, "backtracks": 0},
    {"success": True,  "duration": 60, "backtracks": 2},
    {"success": False, "duration": 90, "backtracks": 5}
]

# %% [markdown]
# Wir werten diese Daten mit Python aus.
#
# ## Aufgabe 1: Erfolgsquote berechnen
#
# Schreibe eine Funktion ```calculate_success_rate(data)```. Diese Funktion erhält das Dicionary ```test_data``` als Parameter und gibt den Anteil der Personen (in Prozent), die die Aufgabe erfolgreich gelöst hat aus.

# %%
test_data = [
    {"success": True,  "duration": 30, "backtracks": 1},
    {"success": False, "duration": 75, "backtracks": 4},
    {"success": True,  "duration": 30, "backtracks": 0},
    {"success": True,  "duration": 60, "backtracks": 2},
    {"success": False, "duration": 90, "backtracks": 5}
]

def calculate_success_rate(data):
    # Dein Code...
    return 0

calculate_success_rate(test_data) # Ausgabe: 60.0

# %% [markdown]
# ## Aufgabe 2: Durchschnittliche Dauer berechnen
#
# Schreibe eine Funktion ```average_duration(data)```. Diese Funktion erhält das Dicionary ```test_data``` als Parameter und gibt die durchschnittliche Bearbeitungszeit aller Testpersonen aus.

# %%
def average_duration(data):
    # Dein Code...
    return 0

average_duration(test_data) # Ausgabe: 57.0

# %% [markdown]
# ## Aufgabe 3: Schwierige Fälle herausfiltern
#
# Schreibe eine Funktion ```find_struggling_users(data, max_duration, max_backtracks)```, die eine Liste aller Sitzungen ausgibt, die _länger_ als ```max_duration``` gedauert haben und _mehr_ Backtracks hatten als ```max_backtracks```. Es ist nicht wichtig, ob die Aufgabe erfolgreich gelöst wurde oder nicht.

# %%
def find_struggling_users(data, max_duration, max_backtracks):
    # Dein Code...
    return 0

find_struggling_users(test_data, 60, 3)
# Ausgabe: [{"success": False, "duration": 75, "backtracks": 4},
# {"success": False, "duration": 90, "backtracks": 5}]

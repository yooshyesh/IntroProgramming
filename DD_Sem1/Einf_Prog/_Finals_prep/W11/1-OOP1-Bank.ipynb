# %% [markdown]
# # OOP1: Einführung in Python
# Mit Geld lässt sich sogar programmieren besser erklären ;)

# %% [markdown]
# ## Aufgabe 1 – Klasse BankAccount erstellen
#
# Erstelle eine Klasse `BankAccount`. Das Konto soll folgende Attribute besitzen:
# - `owner` (Name der Kontoinhaberin)
# - `balance` (Startguthaben, default = 0)
#
# Erstelle ausserdem eine Methode `show_info()`, die Name und Kontostand ausgibt.

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        # TODO: Attribute setzen
        pass
    
    def show_info(self):
        # TODO: Besitzer und Kontostand ausgeben
        pass

# Test
acc = BankAccount("Noé", 100)
acc.show_info()

# %% [markdown]
# ## Aufgabe 2 – Ein- und Auszahlen
#
# Erweitere die Klasse `BankAccount` um zwei Methoden:
# - `deposit(amount)`: erhöht den Kontostand
# - `withdraw(amount)`: verringert den Kontostand
#     - Falls der Kontostand nach der Auszahlung negativ würde, soll eine Meldung ausgegeben und keine Auszahlung vorgenommen werden.

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance
    
    def deposit(self, amount):
        # TODO
        pass

    def withdraw(self, amount):
        # TODO
        pass

# Test
acc = BankAccount("Olivia", 100)
acc.deposit(50)
acc.withdraw(200)
acc.withdraw(50)

# %% [markdown]
# ## Aufgabe 3 – Bank mit mehreren Konten
#
# Erstelle eine Klasse `Bank`, die mehrere Konten verwalten kann.
#
# Die Bank besitzt die folgenden Attribute:
# - `name`
# - `accounts` (Liste von `BankAccount`-Objekten)
#
# Methoden:
# - `add_account(acc)`: Fügt einen neuen `BankAccount` der Liste hinzu.
# - `list_accounts()`: Gibt den Stand von allen `BankAccounts` zurück.

# %%
class Bank:
    def __init__(self, name):
        # TODO
        pass
    
    def add_account(self, acc):
        # TODO
        pass
    
    def list_accounts(self):
        # TODO
        pass

# Test
b = Bank("SuperBank")
b.add_account(BankAccount("Ralph", 200))
b.add_account(BankAccount("Sandra", 300))
b.list_accounts()

# %% [markdown]
# ## Aufgabe 4 – Überweisung zwischen zwei Konten
#
# Füge in ```BankAccount``` eine Methode ```transfer_to(target_account, amount)``` hinzu.
# Die Methode soll:
# 1. von diesem `BankAccount` abheben
# 2. auf das Zielkonto (`target_account`) den gegebenen Betrag (`amount`) einzahlen
# 3. Fehler anzeigen, wenn zu wenig Geld vorhanden ist

# %%
class BankAccount:
    # Nutze deine bisherige Version!
    
    def transfer_to(self, target_account, amount):
        # TODO: erst withdraw, dann deposit
        pass

# Test
a = BankAccount("Anna", 200)
b = BankAccount("Bob", 50)

a.transfer_to(b, 100)
a.show_info()
b.show_info()
